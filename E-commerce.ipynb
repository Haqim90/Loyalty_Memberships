# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('data/Ecomm-Customers.csv')

# %%
data.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
data.shape
# Out:
# (500, 8)

# %%
data.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
#check missing data
data.isna().sum()
# Out:
# Email                   0
# Address                 0
# Avatar                  0
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
data=data.round(2)
data
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
data.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
data['Email'].nunique()
# Out:
# 500

# %%
data['Avatar'].nunique()
#avatar is not a unique identificator of the user, different users has the same Avatar
# Out:
# 138

# %% [markdown]
# Data visualization to check the distribution of the data and outliers

# %%
sns.boxplot(data, y='Yearly Amount Spent');

# %%
sns.histplot(data, x='Yearly Amount Spent');

# %%
sns.boxplot(data, y='Avg. Session Length');

# %%
sns.boxplot(data, y='Time on App');

# %%
sns.boxplot(data, y='Time on Website');

# %%
#we make a list with numerical variables to look for correlations
df=data[['Avg. Session Length', 'Time on App','Time on Website', 'Length of Membership', 'Yearly Amount Spent']]

# %%
sns.pairplot(df)

# %% [markdown]
# From this data lenght of membership is correlated with

# %%
corr=df.corr()

# %%
sns.heatmap(corr, annot=True);

# %% [markdown]
# From the heatmap plot we can conclude that Yearly amount spent is highly correlated with with lenght of membership, this means that the more time members spend as member the more they spend. but this also could mean that they had more time to make purchases, which is kind of logical because member with on year of membership would buy more times if they are consistent.
#
# second variable with correlation with amount spent is the time spent on app

# %% [markdown]
# # Lineal Regression model

# %% [markdown]
# 1.Create Predictor variables 'X' and Target Variable 'y'

# %%
df.columns
# Out:
# Index(['Avg. Session Length', 'Time on App', 'Time on Website',
#        'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
feature_columns=['Avg. Session Length','Time on App','Time on Website' ]
X = df.loc[:, feature_columns]
y = df.loc[:, 'Yearly Amount Spent']

# %% [markdown]
# 2. Split the data into a training set and a testing set.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=100, test_size=0.3)
print(f'X_train shape: {X_train.shape}', 
      f'X_test shape: {X_test.shape}', 
      f'y_train shape: {y_train.shape}', 
      f'X_test shape: {y_test.shape}',
     sep='\n')
# Out:
# X_train shape: (350, 3)
# X_test shape: (150, 3)
# y_train shape: (350,)
# X_test shape: (150,)

# %% [markdown]
# 3. Import the model

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %% [markdown]
# 4. Train the model

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# 5. Model Predictions

# %%
y_pred = model.predict(X_test)

# %%
np.array([y_test[:10], y_pred[:10]]).T
# Out:
# array([[451.58      , 430.4257604 ],
#        [554.72      , 495.35586077],
#        [541.05      , 514.56662845],
#        [442.72      , 480.50565914],
#        [522.4       , 562.22635821],
#        [478.89      , 480.32091291],
#        [392.29      , 385.33659183],
#        [577.27      , 491.27287859],
#        [448.93      , 424.53921511],
#        [541.23      , 475.88517886]])

# %% [markdown]
# 6.Evaluating Predictions

# %%
#Visual inspection
plt.scatter(y_test, y_pred)
plt.xlabel("Test")
plt.ylabel("Predictions")
# Out:
# Text(0, 0.5, 'Predictions')

# %%
#Evaluate the the model, we use mean squered error

# %%
from sklearn.metrics import mean_squared_error

# %%
from sklearn.metrics import r2_score

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 3852.7577504632163
# R-squared: 0.3114551191687438
